# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
API_KEY = os.getenv("DARKSKY_API_KEY")
API_KEY
# Out:
# 'cc342924d3953f6ddb2a1a4731d4987f'

# %%
import requests
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/31.2304,121.4737')
data = response.json()

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'hourly', 'daily', 'flags', 'offset'])

# %%
data['currently']
# Out:
# {'time': 1560142735,
#  'summary': 'Partly Cloudy',
#  'icon': 'partly-cloudy-day',
#  'precipIntensity': 0.0175,
#  'precipProbability': 0.02,
#  'precipType': 'rain',
#  'temperature': 84.19,
#  'apparentTemperature': 88.96,
#  'dewPoint': 70.62,
#  'humidity': 0.64,
#  'pressure': 1003.94,
#  'windSpeed': 4.87,
#  'windGust': 7,
#  'windBearing': 133,
#  'cloudCover': 0.53,
#  'uvIndex': 7,
#  'visibility': 4.53,
#  'ozone': 322.29}

# %%
data['currently']['windSpeed']
# Out:
# 4.87

# %%
feeltemp=data['currently']['apparentTemperature']

# %%
print(feeltemp)
# Out:
# 88.96

# %%
feeltemp-data['currently']['temperature']
# Out:
# 4.769999999999996

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
daily=data['daily']
daily['data'][0]
first_daily=daily['data'][0]

# %%
print(first_daily['moonPhase']*100,'percent')
# Out:
# 25.0 percent

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
print(first_daily)
# Out:
# {'time': 1560096000, 'summary': 'Light rain in the afternoon.', 'icon': 'rain', 'sunriseTime': 1560113455, 'sunsetTime': 1560164334, 'moonPhase': 0.25, 'precipIntensity': 0.0056, 'precipIntensityMax': 0.0251, 'precipIntensityMaxTime': 1560150000, 'precipProbability': 0.26, 'precipType': 'rain', 'temperatureHigh': 85.45, 'temperatureHighTime': 1560139200, 'temperatureLow': 68.24, 'temperatureLowTime': 1560200400, 'apparentTemperatureHigh': 90.75, 'apparentTemperatureHighTime': 1560139200, 'apparentTemperatureLow': 68.79, 'apparentTemperatureLowTime': 1560200400, 'dewPoint': 68.55, 'humidity': 0.74, 'pressure': 1004.32, 'windSpeed': 4.1, 'windGust': 12.62, 'windGustTime': 1560160800, 'windBearing': 110, 'cloudCover': 0.66, 'uvIndex': 7, 'uvIndexTime': 1560135600, 'visibility': 6.69, 'ozone': 318.83, 'temperatureMin': 73.34, 'temperatureMinTime': 1560096000, 'temperatureMax': 85.45, 'temperatureMaxTime': 1560139200, 'apparentTemperatureMin': 74.29, 'apparentTemperatureMinTime': 1560096000, 'apparentTemperatureMax': 90.75, 'apparentTemperatureMaxTime': 1560139200}

# %%
print(first_daily['temperatureHigh']-first_daily['temperatureLow'])
# Out:
# 17.210000000000008

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
daily=data['daily']
daily
# Out:
# {'summary': 'Light rain today, with high temperatures falling to 78°F on Thursday.',
#  'icon': 'rain',
#  'data': [{'time': 1560096000,
#    'summary': 'Light rain in the afternoon.',
#    'icon': 'rain',
#    'sunriseTime': 1560113455,
#    'sunsetTime': 1560164334,
#    'moonPhase': 0.25,
#    'precipIntensity': 0.0056,
#    'precipIntensityMax': 0.0251,
#    'precipIntensityMaxTime': 1560150000,
#    'precipProbability': 0.26,
#    'precipType': 'rain',
#    'temperatureHigh': 85.45,
#    'temperatureHighTime': 1560139200,
#    'temperatureLow': 68.24,
#    'temperatureLowTime': 1560200400,
#    'apparentTemperatureHigh': 90.75,
#    'apparentTemperatureHighTime': 1560139200,
#    'apparentTemperatureLow': 68.79,
#    'apparentTemperatureLowTime': 1560200400,
#    'dewPoint': 68.55,
#    'humidity': 0.74,
#    'pressure': 1004.32,
#    'windSpeed': 4.1,
#    'windGust': 12.62,
#    'windGustTime': 1560160800,
#    'windBearing': 110,
#    'cloudCover': 0.66,
#    'uvIndex': 7,
#    'uvIndexTime': 1560135600,
#    'visibility': 6.69,
#    'ozone': 318.83,
#    'temperatureMin': 73.34,
#    'temperatureMinTime': 1560096000,
#    'temperatureMax': 85.45,
#    'temperatureMaxTime': 1560139200,
#    'apparentTemperatureMin': 74.29,
#    'apparentTemperatureMinTime': 1560096000,
#    'apparentTemperatureMax': 90.75,
#    'apparentTemperatureMaxTime': 1560139200},
#   {'time': 1560182400,
#    'summary': 'Mostly cloudy starting in the evening.',
#    'icon': 'partly-cloudy-night',
#    'sunriseTime': 1560199852,
#    'sunsetTime': 1560250759,
#    'moonPhase': 0.29,
#    'precipIntensity': 0,
#    'precipIntensityMax': 0.0005,
#    'precipIntensityMaxTime': 1560182400,
#    'precipProbability': 0,
#    'temperatureHigh': 80.32,
#    'temperatureHighTime': 1560229200,
#    'temperatureLow': 68.19,
#    'temperatureLowTime': 1560286800,
#    'apparentTemperatureHigh': 80.83,
#    'apparentTemperatureHighTime': 1560229200,
#    'apparentTemperatureLow': 68.61,
#    'apparentTemperatureLowTime': 1560286800,
#    'dewPoint': 60.95,
#    'humidity': 0.64,
#    'pressure': 1008.52,
#    'windSpeed': 7.24,
#    'windGust': 11.91,
#    'windGustTime': 1560243600,
#    'windBearing': 38,
#    'cloudCover': 0.2,
#    'uvIndex': 10,
#    'uvIndexTime': 1560225600,
#    'visibility': 10,
#    'ozone': 328.41,
#    'temperatureMin': 68.24,
#    'temperatureMinTime': 1560200400,
#    'temperatureMax': 80.32,
#    'temperatureMaxTime': 1560229200,
#    'apparentTemperatureMin': 68.79,
#    'apparentTemperatureMinTime': 1560200400,
#    'apparentTemperatureMax': 80.83,
#    'apparentTemperatureMaxTime': 1560229200},
#   {'time': 1560268800,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560286252,
#    'sunsetTime': 1560337183,
#    'moonPhase': 0.32,
#    'precipIntensity': 0,
#    'precipIntensityMax': 0.0002,
#    'precipIntensityMaxTime': 1560330000,
#    'precipProbability': 0,
#    'temperatureHigh': 80.3,
#    'temperatureHighTime': 1560319200,
#    'temperatureLow': 69.25,
#    'temperatureLowTime': 1560373200,
#    'apparentTemperatureHigh': 81.23,
#    'apparentTemperatureHighTime': 1560319200,
#    'apparentTemperatureLow': 69.71,
#    'apparentTemperatureLowTime': 1560373200,
#    'dewPoint': 62.02,
#    'humidity': 0.67,
#    'pressure': 1009.31,
#    'windSpeed': 9.1,
#    'windGust': 19.9,
#    'windGustTime': 1560340800,
#    'windBearing': 125,
#    'cloudCover': 0.83,
#    'uvIndex': 5,
#    'uvIndexTime': 1560308400,
#    'visibility': 10,
#    'ozone': 323.39,
#    'temperatureMin': 68.19,
#    'temperatureMinTime': 1560286800,
#    'temperatureMax': 80.3,
#    'temperatureMaxTime': 1560319200,
#    'apparentTemperatureMin': 68.61,
#    'apparentTemperatureMinTime': 1560286800,
#    'apparentTemperatureMax': 81.23,
#    'apparentTemperatureMaxTime': 1560319200},
#   {'time': 1560355200,
#    'summary': 'Mostly cloudy until afternoon.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560372652,
#    'sunsetTime': 1560423606,
#    'moonPhase': 0.36,
#    'precipIntensity': 0.0032,
#    'precipIntensityMax': 0.0191,
#    'precipIntensityMaxTime': 1560384000,
#    'precipProbability': 0.58,
#    'precipType': 'rain',
#    'temperatureHigh': 77.81,
#    'temperatureHighTime': 1560416400,
#    'temperatureLow': 68.77,
#    'temperatureLowTime': 1560459600,
#    'apparentTemperatureHigh': 77.81,
#    'apparentTemperatureHighTime': 1560416400,
#    'apparentTemperatureLow': 68.77,
#    'apparentTemperatureLowTime': 1560459600,
#    'dewPoint': 61.83,
#    'humidity': 0.7,
#    'pressure': 1008.05,
#    'windSpeed': 10.3,
#    'windGust': 22.33,
#    'windGustTime': 1560362400,
#    'windBearing': 125,
#    'cloudCover': 0.69,
#    'uvIndex': 4,
#    'uvIndexTime': 1560391200,
#    'visibility': 9.75,
#    'ozone': 326.03,
#    'temperatureMin': 69.25,
#    'temperatureMinTime': 1560373200,
#    'temperatureMax': 77.81,
#    'temperatureMaxTime': 1560416400,
#    'apparentTemperatureMin': 69.71,
#    'apparentTemperatureMinTime': 1560373200,
#    'apparentTemperatureMax': 77.81,
#    'apparentTemperatureMaxTime': 1560416400},
#   {'time': 1560441600,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560459054,
#    'sunsetTime': 1560510028,
#    'moonPhase': 0.39,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.0014,
#    'precipIntensityMaxTime': 1560448800,
#    'precipProbability': 0.04,
#    'precipType': 'rain',
#    'temperatureHigh': 82.89,
#    'temperatureHighTime': 1560492000,
#    'temperatureLow': 66.56,
#    'temperatureLowTime': 1560546000,
#    'apparentTemperatureHigh': 82.89,
#    'apparentTemperatureHighTime': 1560492000,
#    'apparentTemperatureLow': 66.77,
#    'apparentTemperatureLowTime': 1560546000,
#    'dewPoint': 58.04,
#    'humidity': 0.56,
#    'pressure': 1007.51,
#    'windSpeed': 7.17,
#    'windGust': 14.51,
#    'windGustTime': 1560520800,
#    'windBearing': 90,
#    'cloudCover': 0,
#    'uvIndex': 9,
#    'uvIndexTime': 1560481200,
#    'visibility': 10,
#    'ozone': 347.2,
#    'temperatureMin': 68.77,
#    'temperatureMinTime': 1560459600,
#    'temperatureMax': 82.89,
#    'temperatureMaxTime': 1560492000,
#    'apparentTemperatureMin': 68.77,
#    'apparentTemperatureMinTime': 1560459600,
#    'apparentTemperatureMax': 82.89,
#    'apparentTemperatureMaxTime': 1560492000},
#   {'time': 1560528000,
#    'summary': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560545457,
#    'sunsetTime': 1560596449,
#    'moonPhase': 0.43,
#    'precipIntensity': 0.0001,
#    'precipIntensityMax': 0.0002,
#    'precipIntensityMaxTime': 1560542400,
#    'precipProbability': 0.07,
#    'precipType': 'rain',
#    'temperatureHigh': 84.25,
#    'temperatureHighTime': 1560574800,
#    'temperatureLow': 68.37,
#    'temperatureLowTime': 1560632400,
#    'apparentTemperatureHigh': 84.25,
#    'apparentTemperatureHighTime': 1560574800,
#    'apparentTemperatureLow': 68.7,
#    'apparentTemperatureLowTime': 1560632400,
#    'dewPoint': 59.73,
#    'humidity': 0.57,
#    'pressure': 1007.69,
#    'windSpeed': 4.82,
#    'windGust': 13.15,
#    'windGustTime': 1560528000,
#    'windBearing': 102,
#    'cloudCover': 0.27,
#    'uvIndex': 6,
#    'uvIndexTime': 1560564000,
#    'visibility': 10,
#    'ozone': 324.54,
#    'temperatureMin': 66.56,
#    'temperatureMinTime': 1560546000,
#    'temperatureMax': 84.25,
#    'temperatureMaxTime': 1560574800,
#    'apparentTemperatureMin': 66.77,
#    'apparentTemperatureMinTime': 1560546000,
#    'apparentTemperatureMax': 84.25,
#    'apparentTemperatureMaxTime': 1560574800},
#   {'time': 1560614400,
#    'summary': 'Mostly cloudy in the morning.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560631862,
#    'sunsetTime': 1560682868,
#    'moonPhase': 0.46,
#    'precipIntensity': 0,
#    'precipIntensityMax': 0,
#    'precipProbability': 0,
#    'temperatureHigh': 82.14,
#    'temperatureHighTime': 1560664800,
#    'temperatureLow': 69.8,
#    'temperatureLowTime': 1560715200,
#    'apparentTemperatureHigh': 82.28,
#    'apparentTemperatureHighTime': 1560664800,
#    'apparentTemperatureLow': 70.15,
#    'apparentTemperatureLowTime': 1560715200,
#    'dewPoint': 61.34,
#    'humidity': 0.63,
#    'pressure': 1010.31,
#    'windSpeed': 8.17,
#    'windGust': 16.28,
#    'windGustTime': 1560697200,
#    'windBearing': 93,
#    'cloudCover': 0.32,
#    'uvIndex': 10,
#    'uvIndexTime': 1560654000,
#    'visibility': 10,
#    'ozone': 321.51,
#    'temperatureMin': 68.37,
#    'temperatureMinTime': 1560632400,
#    'temperatureMax': 82.14,
#    'temperatureMaxTime': 1560664800,
#    'apparentTemperatureMin': 68.7,
#    'apparentTemperatureMinTime': 1560632400,
#    'apparentTemperatureMax': 82.28,
#    'apparentTemperatureMaxTime': 1560664800},
#   {'time': 1560700800,
#    'summary': 'Overcast throughout the day.',
#    'icon': 'cloudy',
#    'sunriseTime': 1560718268,
#    'sunsetTime': 1560769287,
#    'moonPhase': 0.49,
#    'precipIntensity': 0.0001,
#    'precipIntensityMax': 0.0006,
#    'precipIntensityMaxTime': 1560718800,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperatureHigh': 81.78,
#    'temperatureHighTime': 1560751200,
#    'temperatureLow': 70.42,
#    'temperatureLowTime': 1560801600,
#    'apparentTemperatureHigh': 82.09,
#    'apparentTemperatureHighTime': 1560751200,
#    'apparentTemperatureLow': 71.23,
#    'apparentTemperatureLowTime': 1560801600,
#    'dewPoint': 61.69,
#    'humidity': 0.63,
#    'pressure': 1011.16,
#    'windSpeed': 10.84,
#    'windGust': 19.58,
#    'windGustTime': 1560776400,
#    'windBearing': 118,
#    'cloudCover': 0.89,
#    'uvIndex': 5,
#    'uvIndexTime': 1560740400,
#    'visibility': 10,
#    'ozone': 310.27,
#    'temperatureMin': 69.8,
#    'temperatureMinTime': 1560715200,
#    'temperatureMax': 81.78,
#    'temperatureMaxTime': 1560751200,
#    'apparentTemperatureMin': 70.15,
#    'apparentTemperatureMinTime': 1560715200,
#    'apparentTemperatureMax': 82.09,
#    'apparentTemperatureMaxTime': 1560751200}]}

# %%
for d in daily['data']:
    print(d['temperatureHigh'])
    if d['temperatureHigh']>77:
        print('hot')
    elif d['temperatureHigh']<=77 and d['temperatureHigh']>68:
        print(warm)
    else:
        print(cold)
# Out:
# 85.45
# hot
# 80.32
# hot
# 80.3
# hot
# 77.81
# hot
# 82.89
# hot
# 84.25
# hot
# 82.14
# hot
# 81.78
# hot

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
hot_temp=0
hot_day=0
for d in daily['data']:
    if d['temperatureHigh']>hot_temp:
        hot_temp=d['temperatureHigh']
        hot_day=d['time']
print(hot_day,':',hot_temp)
# Out:
# 1560096000 : 85.45

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
import requests
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/25.7617,-80.1918')
miami = response.json()

# %%
miami.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
miami['hourly']['data']
# Out:
# [{'time': 1560142800,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0058,
#   'precipProbability': 0.4,
#   'precipType': 'rain',
#   'temperature': 79.83,
#   'apparentTemperature': 84.97,
#   'dewPoint': 76.08,
#   'humidity': 0.88,
#   'pressure': 1016.13,
#   'windSpeed': 4.64,
#   'windGust': 5.75,
#   'windBearing': 165,
#   'cloudCover': 0.07,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 299.51},
#  {'time': 1560146400,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 79.22,
#   'apparentTemperature': 83.58,
#   'dewPoint': 76.09,
#   'humidity': 0.9,
#   'pressure': 1016.04,
#   'windSpeed': 4.46,
#   'windGust': 5.57,
#   'windBearing': 184,
#   'cloudCover': 0.18,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 299.43},
#  {'time': 1560150000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0054,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 79.66,
#   'apparentTemperature': 84.55,
#   'dewPoint': 76.04,
#   'humidity': 0.89,
#   'pressure': 1015.94,
#   'windSpeed': 5.71,
#   'windGust': 7.13,
#   'windBearing': 181,
#   'cloudCover': 0.27,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 299.61},
#  {'time': 1560153600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0073,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 79.9,
#   'apparentTemperature': 85.06,
#   'dewPoint': 75.95,
#   'humidity': 0.88,
#   'pressure': 1015.56,
#   'windSpeed': 6.44,
#   'windGust': 9.27,
#   'windBearing': 174,
#   'cloudCover': 0.35,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 299.86},
#  {'time': 1560157200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0099,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 80.15,
#   'apparentTemperature': 85.76,
#   'dewPoint': 75.8,
#   'humidity': 0.87,
#   'pressure': 1015.57,
#   'windSpeed': 6.47,
#   'windGust': 10.02,
#   'windBearing': 171,
#   'cloudCover': 0.35,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 300.18},
#  {'time': 1560160800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0062,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 80.89,
#   'apparentTemperature': 86.94,
#   'dewPoint': 75.58,
#   'humidity': 0.84,
#   'pressure': 1015.62,
#   'windSpeed': 7.21,
#   'windGust': 10.5,
#   'windBearing': 174,
#   'cloudCover': 0.4,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 300.37},
#  {'time': 1560164400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0023,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 81.88,
#   'apparentTemperature': 88.62,
#   'dewPoint': 75.27,
#   'humidity': 0.81,
#   'pressure': 1015.89,
#   'windSpeed': 7.43,
#   'windGust': 10.57,
#   'windBearing': 175,
#   'cloudCover': 0.4,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 300.48},
#  {'time': 1560168000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0022,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 83.43,
#   'apparentTemperature': 91.13,
#   'dewPoint': 75.07,
#   'humidity': 0.76,
#   'pressure': 1016.12,
#   'windSpeed': 7.84,
#   'windGust': 11.66,
#   'windBearing': 171,
#   'cloudCover': 0.42,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 300.81},
#  {'time': 1560171600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0028,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 85.46,
#   'apparentTemperature': 94.03,
#   'dewPoint': 74.79,
#   'humidity': 0.71,
#   'pressure': 1016.51,
#   'windSpeed': 8.2,
#   'windGust': 11.6,
#   'windBearing': 172,
#   'cloudCover': 0.38,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 301.82},
#  {'time': 1560175200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0048,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 87.23,
#   'apparentTemperature': 96.3,
#   'dewPoint': 74.55,
#   'humidity': 0.66,
#   'pressure': 1017.08,
#   'windSpeed': 8.24,
#   'windGust': 10.98,
#   'windBearing': 169,
#   'cloudCover': 0.4,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 302.92},
#  {'time': 1560178800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0074,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 88.19,
#   'apparentTemperature': 97.3,
#   'dewPoint': 74.25,
#   'humidity': 0.64,
#   'pressure': 1017.42,
#   'windSpeed': 8.85,
#   'windGust': 11.15,
#   'windBearing': 165,
#   'cloudCover': 0.44,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 303.1},
#  {'time': 1560182400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0143,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 88.53,
#   'apparentTemperature': 97.6,
#   'dewPoint': 74.1,
#   'humidity': 0.63,
#   'pressure': 1017.61,
#   'windSpeed': 9.56,
#   'windGust': 11.77,
#   'windBearing': 163,
#   'cloudCover': 0.56,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 301.49},
#  {'time': 1560186000,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.037,
#   'precipProbability': 0.19,
#   'precipType': 'rain',
#   'temperature': 88.35,
#   'apparentTemperature': 96.8,
#   'dewPoint': 73.56,
#   'humidity': 0.62,
#   'pressure': 1017.57,
#   'windSpeed': 9.65,
#   'windGust': 11.7,
#   'windBearing': 169,
#   'cloudCover': 0.58,
#   'uvIndex': 8,
#   'visibility': 9.79,
#   'ozone': 298.86},
#  {'time': 1560189600,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.055,
#   'precipProbability': 0.24,
#   'precipType': 'rain',
#   'temperature': 88.34,
#   'apparentTemperature': 96.92,
#   'dewPoint': 73.69,
#   'humidity': 0.62,
#   'pressure': 1017.42,
#   'windSpeed': 9.69,
#   'windGust': 12.1,
#   'windBearing': 172,
#   'cloudCover': 0.82,
#   'uvIndex': 6,
#   'visibility': 8.2,
#   'ozone': 296.6},
#  {'time': 1560193200,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0658,
#   'precipProbability': 0.37,
#   'precipType': 'rain',
#   'temperature': 89.73,
#   'apparentTemperature': 97.91,
#   'dewPoint': 72.89,
#   'humidity': 0.58,
#   'pressure': 1016.64,
#   'windSpeed': 8.6,
#   'windGust': 9.4,
#   'windBearing': 184,
#   'cloudCover': 0.71,
#   'uvIndex': 6,
#   'visibility': 7.43,
#   'ozone': 295.11},
#  {'time': 1560196800,
#   'summary': 'Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0433,
#   'precipProbability': 0.31,
#   'precipType': 'rain',
#   'temperature': 88.93,
#   'apparentTemperature': 96.89,
#   'dewPoint': 72.91,
#   'humidity': 0.59,
#   'pressure': 1016.14,
#   'windSpeed': 7.78,
#   'windGust': 8.49,
#   'windBearing': 188,
#   'cloudCover': 0.6,
#   'uvIndex': 5,
#   'visibility': 9.97,
#   'ozone': 293.97},
#  {'time': 1560200400,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0307,
#   'precipProbability': 0.26,
#   'precipType': 'rain',
#   'temperature': 88.23,
#   'apparentTemperature': 96.11,
#   'dewPoint': 73.03,
#   'humidity': 0.61,
#   'pressure': 1015.81,
#   'windSpeed': 7,
#   'windGust': 7.75,
#   'windBearing': 186,
#   'cloudCover': 0.52,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 292.98},
#  {'time': 1560204000,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0289,
#   'precipProbability': 0.25,
#   'precipType': 'rain',
#   'temperature': 87.18,
#   'apparentTemperature': 95.02,
#   'dewPoint': 73.33,
#   'humidity': 0.64,
#   'pressure': 1015.79,
#   'windSpeed': 6.25,
#   'windGust': 7.18,
#   'windBearing': 175,
#   'cloudCover': 0.49,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 292.04},
#  {'time': 1560207600,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0321,
#   'precipProbability': 0.26,
#   'precipType': 'rain',
#   'temperature': 86.12,
#   'apparentTemperature': 93.96,
#   'dewPoint': 73.73,
#   'humidity': 0.67,
#   'pressure': 1015.94,
#   'windSpeed': 5.58,
#   'windGust': 6.7,
#   'windBearing': 175,
#   'cloudCover': 0.49,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.4},
#  {'time': 1560211200,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0311,
#   'precipProbability': 0.22,
#   'precipType': 'rain',
#   'temperature': 84.97,
#   'apparentTemperature': 92.65,
#   'dewPoint': 74.08,
#   'humidity': 0.7,
#   'pressure': 1016.14,
#   'windSpeed': 5.32,
#   'windGust': 6.47,
#   'windBearing': 186,
#   'cloudCover': 0.49,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.07},
#  {'time': 1560214800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.016,
#   'precipProbability': 0.15,
#   'precipType': 'rain',
#   'temperature': 84.17,
#   'apparentTemperature': 91.66,
#   'dewPoint': 74.3,
#   'humidity': 0.72,
#   'pressure': 1016.41,
#   'windSpeed': 5.57,
#   'windGust': 6.55,
#   'windBearing': 173,
#   'cloudCover': 0.45,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.54},
#  {'time': 1560218400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0028,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 83.63,
#   'apparentTemperature': 90.98,
#   'dewPoint': 74.49,
#   'humidity': 0.74,
#   'pressure': 1016.75,
#   'windSpeed': 6.12,
#   'windGust': 6.86,
#   'windBearing': 165,
#   'cloudCover': 0.38,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 292.4},
#  {'time': 1560222000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 82.98,
#   'apparentTemperature': 90.01,
#   'dewPoint': 74.57,
#   'humidity': 0.76,
#   'pressure': 1016.88,
#   'windSpeed': 6.34,
#   'windGust': 7,
#   'windBearing': 176,
#   'cloudCover': 0.34,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 292.8},
#  {'time': 1560225600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 82.37,
#   'apparentTemperature': 88.97,
#   'dewPoint': 74.54,
#   'humidity': 0.77,
#   'pressure': 1016.63,
#   'windSpeed': 6.15,
#   'windGust': 6.83,
#   'windBearing': 186,
#   'cloudCover': 0.36,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.91},
#  {'time': 1560229200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 81.79,
#   'apparentTemperature': 87.94,
#   'dewPoint': 74.45,
#   'humidity': 0.79,
#   'pressure': 1016.24,
#   'windSpeed': 5.87,
#   'windGust': 6.5,
#   'windBearing': 196,
#   'cloudCover': 0.39,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.58},
#  {'time': 1560232800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 81.36,
#   'apparentTemperature': 87.09,
#   'dewPoint': 74.28,
#   'humidity': 0.79,
#   'pressure': 1015.9,
#   'windSpeed': 5.5,
#   'windGust': 6.05,
#   'windBearing': 203,
#   'cloudCover': 0.42,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 289.5},
#  {'time': 1560236400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0003,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperature': 81.04,
#   'apparentTemperature': 86.44,
#   'dewPoint': 74.09,
#   'humidity': 0.8,
#   'pressure': 1015.78,
#   'windSpeed': 4.88,
#   'windGust': 5.32,
#   'windBearing': 209,
#   'cloudCover': 0.46,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 289.27},
#  {'time': 1560240000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0007,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperature': 80.34,
#   'apparentTemperature': 85.07,
#   'dewPoint': 73.85,
#   'humidity': 0.81,
#   'pressure': 1015.75,
#   'windSpeed': 4.12,
#   'windGust': 4.46,
#   'windBearing': 213,
#   'cloudCover': 0.51,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 289.3},
#  {'time': 1560243600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0011,
#   'precipProbability': 0.03,
#   'precipType': 'rain',
#   'temperature': 80.03,
#   'apparentTemperature': 84.43,
#   'dewPoint': 73.65,
#   'humidity': 0.81,
#   'pressure': 1015.85,
#   'windSpeed': 3.6,
#   'windGust': 3.91,
#   'windBearing': 212,
#   'cloudCover': 0.55,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 289.69},
#  {'time': 1560247200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0016,
#   'precipProbability': 0.03,
#   'precipType': 'rain',
#   'temperature': 80.14,
#   'apparentTemperature': 84.56,
#   'dewPoint': 73.49,
#   'humidity': 0.8,
#   'pressure': 1016.09,
#   'windSpeed': 3.36,
#   'windGust': 3.59,
#   'windBearing': 207,
#   'cloudCover': 0.56,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.24},
#  {'time': 1560250800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0043,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 80.81,
#   'apparentTemperature': 85.68,
#   'dewPoint': 73.38,
#   'humidity': 0.78,
#   'pressure': 1016.44,
#   'windSpeed': 3.31,
#   'windGust': 3.45,
#   'windBearing': 199,
#   'cloudCover': 0.57,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.15},
#  {'time': 1560254400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0067,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 82.17,
#   'apparentTemperature': 87.89,
#   'dewPoint': 73.36,
#   'humidity': 0.75,
#   'pressure': 1016.76,
#   'windSpeed': 3.5,
#   'windGust': 3.6,
#   'windBearing': 191,
#   'cloudCover': 0.58,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 291.83},
#  {'time': 1560258000,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0041,
#   'precipProbability': 0.03,
#   'precipType': 'rain',
#   'temperature': 84.44,
#   'apparentTemperature': 91.42,
#   'dewPoint': 73.54,
#   'humidity': 0.7,
#   'pressure': 1017.01,
#   'windSpeed': 3.98,
#   'windGust': 4.39,
#   'windBearing': 182,
#   'cloudCover': 0.68,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 292.3},
#  {'time': 1560261600,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0009,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperature': 86.33,
#   'apparentTemperature': 94.34,
#   'dewPoint': 73.82,
#   'humidity': 0.66,
#   'pressure': 1017.24,
#   'windSpeed': 4.6,
#   'windGust': 5.7,
#   'windBearing': 172,
#   'cloudCover': 0.82,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 292.64},
#  {'time': 1560265200,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 87.87,
#   'apparentTemperature': 96.58,
#   'dewPoint': 73.97,
#   'humidity': 0.64,
#   'pressure': 1017.3,
#   'windSpeed': 5.29,
#   'windGust': 6.75,
#   'windBearing': 163,
#   'cloudCover': 0.92,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 292.65},
#  {'time': 1560268800,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 88.95,
#   'apparentTemperature': 97.8,
#   'dewPoint': 73.76,
#   'humidity': 0.61,
#   'pressure': 1017.2,
#   'windSpeed': 6.07,
#   'windGust': 7.01,
#   'windBearing': 158,
#   'cloudCover': 0.91,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 292.47},
#  {'time': 1560272400,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 90.28,
#   'apparentTemperature': 99.11,
#   'dewPoint': 73.37,
#   'humidity': 0.58,
#   'pressure': 1016.93,
#   'windSpeed': 6.96,
#   'windGust': 7.02,
#   'windBearing': 154,
#   'cloudCover': 0.89,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 292.1},
#  {'time': 1560276000,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0003,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperature': 90.96,
#   'apparentTemperature': 99.68,
#   'dewPoint': 73.09,
#   'humidity': 0.56,
#   'pressure': 1016.57,
#   'windSpeed': 7.87,
#   'windGust': 7.91,
#   'windBearing': 152,
#   'cloudCover': 0.85,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 291.72},
#  {'time': 1560279600,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0004,
#   'precipProbability': 0.03,
#   'precipType': 'rain',
#   'temperature': 91.45,
#   'apparentTemperature': 100.4,
#   'dewPoint': 73.17,
#   'humidity': 0.55,
#   'pressure': 1016.02,
#   'windSpeed': 8.89,
#   'windGust': 8.98,
#   'windBearing': 153,
#   'cloudCover': 0.74,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 291.48},
#  {'time': 1560283200,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0014,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 90.78,
#   'apparentTemperature': 99.83,
#   'dewPoint': 73.44,
#   'humidity': 0.57,
#   'pressure': 1015.38,
#   'windSpeed': 9.87,
#   'windGust': 11.02,
#   'windBearing': 155,
#   'cloudCover': 0.6,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 291.29},
#  {'time': 1560286800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0023,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 89.59,
#   'apparentTemperature': 98.52,
#   'dewPoint': 73.65,
#   'humidity': 0.6,
#   'pressure': 1014.95,
#   'windSpeed': 10.58,
#   'windGust': 12.66,
#   'windBearing': 157,
#   'cloudCover': 0.49,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 291.57},
#  {'time': 1560290400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0023,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 88.05,
#   'apparentTemperature': 96.58,
#   'dewPoint': 73.74,
#   'humidity': 0.63,
#   'pressure': 1014.88,
#   'windSpeed': 11.01,
#   'windGust': 13.78,
#   'windBearing': 164,
#   'cloudCover': 0.43,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 292.6},
#  {'time': 1560294000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.005,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 86.55,
#   'apparentTemperature': 94.61,
#   'dewPoint': 73.8,
#   'humidity': 0.66,
#   'pressure': 1015.01,
#   'windSpeed': 11.2,
#   'windGust': 14.5,
#   'windBearing': 171,
#   'cloudCover': 0.4,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 294.05},
#  {'time': 1560297600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0117,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 85.32,
#   'apparentTemperature': 92.97,
#   'dewPoint': 73.87,
#   'humidity': 0.69,
#   'pressure': 1015.29,
#   'windSpeed': 10.88,
#   'windGust': 14.33,
#   'windBearing': 173,
#   'cloudCover': 0.38,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 295.63},
#  {'time': 1560301200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.028,
#   'precipProbability': 0.19,
#   'precipType': 'rain',
#   'temperature': 84.39,
#   'apparentTemperature': 91.67,
#   'dewPoint': 73.93,
#   'humidity': 0.71,
#   'pressure': 1015.85,
#   'windSpeed': 9.78,
#   'windGust': 12.76,
#   'windBearing': 164,
#   'cloudCover': 0.38,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 297.4},
#  {'time': 1560304800,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0598,
#   'precipProbability': 0.25,
#   'precipType': 'rain',
#   'temperature': 83.44,
#   'apparentTemperature': 90.31,
#   'dewPoint': 74.02,
#   'humidity': 0.73,
#   'pressure': 1016.57,
#   'windSpeed': 8.31,
#   'windGust': 10.33,
#   'windBearing': 171,
#   'cloudCover': 0.38,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 299.35},
#  {'time': 1560308400,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0767,
#   'precipProbability': 0.27,
#   'precipType': 'rain',
#   'temperature': 82.47,
#   'apparentTemperature': 88.77,
#   'dewPoint': 74,
#   'humidity': 0.76,
#   'pressure': 1016.99,
#   'windSpeed': 6.97,
#   'windGust': 8.25,
#   'windBearing': 193,
#   'cloudCover': 0.37,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 300.86},
#  {'time': 1560312000,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0451,
#   'precipProbability': 0.24,
#   'precipType': 'rain',
#   'temperature': 81.79,
#   'apparentTemperature': 87.59,
#   'dewPoint': 73.9,
#   'humidity': 0.77,
#   'pressure': 1016.91,
#   'windSpeed': 6.15,
#   'windGust': 6.93,
#   'windBearing': 187,
#   'cloudCover': 0.46,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 301.88},
#  {'time': 1560315600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0098,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 81.13,
#   'apparentTemperature': 86.4,
#   'dewPoint': 73.75,
#   'humidity': 0.78,
#   'pressure': 1016.56,
#   'windSpeed': 5.5,
#   'windGust': 5.95,
#   'windBearing': 185,
#   'cloudCover': 0.58,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 302.55}]

# %%
for h in miami['hourly']['data']:
    if h['cloudCover']>0.5:
        print(h['time'],':',h['temperature'],'cloudy')
    else:
        print(h['time'],':',h['temperature'])
# Out:
# 1560142800 : 79.83
# 1560146400 : 79.22
# 1560150000 : 79.66
# 1560153600 : 79.9
# 1560157200 : 80.15
# 1560160800 : 80.89
# 1560164400 : 81.88
# 1560168000 : 83.43
# 1560171600 : 85.46
# 1560175200 : 87.23
# 1560178800 : 88.19
# 1560182400 : 88.53 cloudy
# 1560186000 : 88.35 cloudy
# 1560189600 : 88.34 cloudy
# 1560193200 : 89.73 cloudy
# 1560196800 : 88.93 cloudy
# 1560200400 : 88.23 cloudy
# 1560204000 : 87.18
# 1560207600 : 86.12
# 1560211200 : 84.97
# 1560214800 : 84.17
# 1560218400 : 83.63
# 1560222000 : 82.98
# 1560225600 : 82.37
# 1560229200 : 81.79
# 1560232800 : 81.36
# 1560236400 : 81.04
# 1560240000 : 80.34 cloudy
# 1560243600 : 80.03 cloudy
# 1560247200 : 80.14 cloudy
# 1560250800 : 80.81 cloudy
# 1560254400 : 82.17 cloudy
# 1560258000 : 84.44 cloudy
# 1560261600 : 86.33 cloudy
# 1560265200 : 87.87 cloudy
# 1560268800 : 88.95 cloudy
# 1560272400 : 90.28 cloudy
# 1560276000 : 90.96 cloudy
# 1560279600 : 91.45 cloudy
# 1560283200 : 90.78 cloudy
# 1560286800 : 89.59
# 1560290400 : 88.05
# 1560294000 : 86.55
# 1560297600 : 85.32
# 1560301200 : 84.39
# 1560304800 : 83.44
# 1560308400 : 82.47
# 1560312000 : 81.79
# 1560315600 : 81.13 cloudy
# 49

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
tmp_cnt=0
for h in miami['hourly']['data']:
    if h['temperature']>85:
        tmp_cnt=tmp_cnt+1
print((tmp_cnt/len(miami['hourly']['data']))*100,'percent')
# Out:
# 44.89795918367347 percent

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
import requests
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1356393600')
cpark = response.json()

# %%
print(cpark['currently']['temperature'])
# Out:
# 36.81

# %%
import requests
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1198540800')
cpark_2007 = response.json()
print(cpark_2007['currently']['temperature'])

import requests
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1135468800')
cpark_2005 = response.json()
print(cpark_2005['currently']['temperature'])
# Out:
# 41.25
# 42.88
